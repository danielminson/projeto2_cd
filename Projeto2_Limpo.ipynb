# %% [markdown]
# ---
# # Projeto 2 - Ciência dos Dados
#
# Nome: Daniel Pucciariello
#
# Nome: Stephanie Liu
#
# ---

# %% [markdown]
# ___
# # Classificador automático de sentimento
# ## Preparando o ambiente no jupyter:

# %%
# %%capture

#Instalando o tweepy
# !pip install tweepy

# %%
import tweepy
import math
import os.path
import pandas as pd
import json
from random import shuffle

# %%
import re 

def cleanup(text):
    """
        Função de limpeza muito simples que troca alguns sinais básicos por espaços
    """
    import string
    punctuation = '[!-.:?;/]' # Note que os sinais [] são delimitadores de um conjunto.
    pattern = re.compile(punctuation)
    
    text_subbed = re.sub(pattern, ' ', text)
    text_subbed=text_subbed.replace("\n", " ")
    text_subbed=text_subbed.replace("…", " ")
    text_subbed=text_subbed.replace("@", " ")
    text_subbed=text_subbed.replace("rt", "")
    text_subbed=text_subbed.replace("https", "")
    
    return text_subbed
#tirar coisas com https

# %%
#Dados de autenticação do twitter:

#Coloque aqui o identificador da conta no twitter: @fulano

#leitura do arquivo no formato JSON
with open('auth.pass') as fp:    
    data = json.load(fp)

#Configurando a biblioteca. Não modificar
auth = tweepy.OAuthHandler(data['consumer_key'], data['consumer_secret'])
auth.set_access_token(data['access_token'], data['access_token_secret'])

# %% [markdown]
# ___
# ### Montando o Classificador Naive-Bayes
#
# Considerando apenas as mensagens da planilha Treinamento, ensine  seu classificador.
#
# ---

# %%
data_treinamento = pd.read_excel("Excel_pastel.xlsx",sheet_name="Treinamento")

# %%
irrelevantes_raw = " ".join(data_treinamento[data_treinamento.Classe<=1].Treinamento)

# %%
irrelevantes = cleanup(irrelevantes_raw)
#irrelevantes

# %%
tabela_relativa_ngostam_irrelevantes = pd.Series(irrelevantes.lower().split()).value_counts(True)
tabela_absoluta_ngostam_irrelevantes = pd.Series(irrelevantes.lower().split()).value_counts(False)

# %%
tabela_relativa_gostam_raw = " ".join(data_treinamento[data_treinamento.Classe==2].Treinamento)

# %%
tabela_relativa_gostam = pd.Series(tabela_relativa_gostam_raw.lower().split()).value_counts(True)
tabela_absoluta_gostam = pd.Series(tabela_relativa_gostam_raw.lower().split()).value_counts(False)

# %%
Multiplicando_tabela_naogostam = tabela_relativa_ngostam_irrelevantes*2

# %%
tudo=irrelevantes_raw + tabela_relativa_gostam_raw
tudo=cleanup(tudo)
tudo_absoluto=pd.Series(tudo.lower().split()).value_counts(False)
# Out:
# 1947

# %%
data_teste = pd.read_excel("Excel_pastel.xlsx",sheet_name="Teste")
tudo_absoluto
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-18cd7903ba67> in <module>
# ----> 1 data_teste = pd.read_excel("Excel_pastel.xlsx",sheet_name="Teste")
#       2 tudo_absoluto
#
# NameError: name 'pd' is not defined

# %%
#data_teste_idx= data_teste.set_index("Teste")
lista=[]
lista2=[]
for i in data_teste.Teste:
    gosta=tabela_absoluta_gostam[i.split()+1].prod()/tudo_absoluto[i.split()].prod()
    ngosta=tabela_absoluta_ngostam_irrelevantes[i.split()].prod()/tudo_absoluto[i.split()].prod()
    if gosta>ngosta:
        valor=2
    elif gosta<ngosta:
        valor=1
    elif gosta==0:
        valor=3
    elif ngosta==0:
        valor=4
    lista.append(valor)
    lista2.append(tudo_absoluto[i.split()].prod())
data_teste.Classe = lista
lista2
# Out:
# [1452447360000.0,
#  289170000.0,
#  1.606784937645888e+16,
#  7578567360000,
#  714000.0,
#  7.99224287637888e+20,
#  659736000,
#  2.6299880742147756e+28,
#  9539640000.0,
#  114000.0,
#  516000.0,
#  557366210151660000,
#  1.85497407583488e+20,
#  158436000.0,
#  91267171003008000,
#  17772480000.0,
#  244188000.0,
#  448777497168000.0,
#  9808260000.0,
#  6.534763907822909e+31,
#  81465300000,
#  40896700000000,
#  59406048000.0,
#  4.761561672e+18,
#  1.05747172267275e+16,
#  2391902556120000,
#  7.1669286147625545e+25,
#  5520585962823876608,
#  4.683612280381967e+43,
#  6.424277693439375e+18,
#  199676897280.0,
#  1.27196446341888e+22,
#  1.9266164323944402e+46,
#  3.1151328293103767e+29,
#  9.252877390848e+16,
#  7.785972585022697e+41,
#  70463250000.0,
#  1.6581756640629888e+28,
#  94500.0,
#  112319200224000.0,
#  4169760000.0,
#  3.5112744243894294e+26,
#  958926276000.0,
#  1.40289119397e+16,
#  3.314133416625816e+29,
#  1.8653304024e+16,
#  3.325234636810836e+38,
#  1.40151011882112e+18,
#  9.343079373402799e+39,
#  1145129216000,
#  -5925976430240770048,
#  2.9147322393609506e+40,
#  1.1166877939002664e+33,
#  410760.0,
#  6.7847074611631485e+40,
#  1.132020384768e+17,
#  9072000.0,
#  2056320000.0,
#  2.5879801511368804e+28,
#  82121355912960000,
#  60000,
#  1.0,
#  15554256000.0,
#  73920000.0,
#  2.04375650992128e+17,
#  5303760000.0,
#  331688700000,
#  8.952982010817448e+26,
#  112000.0,
#  1.357815276994176e+16,
#  963693158400000.0,
#  9000.0,
#  835585632000.0,
#  1373217300000.0,
#  7236560217600000.0,
#  9.43578248256e+16,
#  9409377600000.0,
#  4.8298420025856e+16,
#  410000.0,
#  1956000.0,
#  5.451886075209564e+21,
#  1.03627045896192e+19,
#  2.4188306619900536e+28,
#  571771200000.0,
#  6.2951629758387136e+29,
#  2456017200.0,
#  14172930422784.0,
#  16955827200.0,
#  1.7756914622612674e+26,
#  73867500.0,
#  402910200000.0,
#  2500.0,
#  525668879736000.0,
#  986950656000000.0,
#  4.696548743878174e+26,
#  3.034738621736315e+25,
#  4374606652416000.0,
#  159636984000.0,
#  6.871012115297813e+22,
#  2446948503816615168,
#  7800000.0,
#  1.7489376884826e+17,
#  5.951371153461327e+48,
#  5.0410149310768265e+22,
#  2.454847742850048e+21,
#  7.2924259183776e+16,
#  5295868524198000.0,
#  1.3979013525396134e+36,
#  1.288401395056327e+25,
#  9.075892396032e+16,
#  1162334880000.0,
#  2054220000.0,
#  7776.0,
#  5336906097600000.0,
#  2.4876109310976e+17,
#  250214850000.0,
#  9.73303242912e+23,
#  2364768000,
#  -1135584555591794688,
#  6.42063480274944e+18,
#  1.0175631757344e+17,
#  20447532000.0,
#  38864448000.0,
#  3723847464960.0,
#  1.4295892013352374e+24,
#  2641920.0,
#  4.6116114990637073e+27,
#  1.2990475547973e+25,
#  891936000,
#  27241629696000.0,
#  621274500.0,
#  13045321536624000,
#  612612000,
#  1.5675097663386662e+20,
#  201164721912000.0,
#  4.170648264707622e+22,
#  558943032384000.0,
#  3.74913207631872e+19,
#  188148460500,
#  1630000,
#  44505000.0,
#  29095470904500.0,
#  36971235.0,
#  1.97394717671424e+18,
#  1.3958834553151488e+20,
#  1.0777013243106671e+28,
#  578108340000.0,
#  6.854468594448384e+18,
#  2124738000,
#  2.0486018157696e+17,
#  562016000,
#  4.716597444959425e+30,
#  19120896000,
#  5.183343183965999e+28,
#  1.27196446341888e+22,
#  3149760000,
#  4.7195275615488e+16,
#  2.7775962182215676e+23,
#  59926500.0,
#  5072256.0,
#  3428399520000.0,
#  3.0374456313494426e+24,
#  3096000.0,
#  4308050880000,
#  2.0378428416e+17,
#  5.358930152538251e+21,
#  1.9039584594666374e+27,
#  1.885772109312e+19,
#  5661749184000.0,
#  4248030786598813696,
#  2.422016771328e+17,
#  2000.0,
#  5.7453395212493275e+19,
#  22294512866304.0,
#  5948573904.0,
#  5402346808320000.0,
#  289170000.0,
#  334372500.0,
#  1.3556595392879616e+20,
#  9539640000.0,
#  659003904000,
#  2.236197685903635e+24,
#  7.650842977008e+16,
#  278528544000.0,
#  2802996900000.0,
#  4539010148040513536,
#  25390018500.0,
#  91267171003008000,
#  2.3014466905038336e+19,
#  59381637840000.0,
#  1.3045321536624e+16,
#  8475300000.0,
#  2.0378428416e+17,
#  244188000.0,
#  2.1357170830768817e+24,
#  6.963093311521538e+43,
#  2360467200000,
#  1684935564000,
#  1806000,
#  26634342000.0,
#  3000638550000,
#  31410570744000.0,
#  6205584000.0,
#  607068000.0,
#  57506428224000,
#  698927591376000.0,
#  341658000.0,
#  2.3338398259298304e+20,
#  4.683612280381967e+43,
#  1.3256727447830106e+22,
#  5.71171360032e+17,
#  6.424277693439375e+18,
#  5.114251852950417e+23,
#  199676897280.0,
#  1.9266164323944402e+46,
#  1.27196446341888e+22,
#  3.6563838861312e+16,
#  9.252877390848e+16,
#  7.785972585022697e+41,
#  30086184960000.0,
#  3234742093174046720,
#  4169760000.0,
#  7399757933568000,
#  3.5112744243894294e+26,
#  231747264000000.0,
#  3.838866571060881e+52,
#  1.40289119397e+16,
#  958926276000.0,
#  58302335520000,
#  8.045995288945842e+26,
#  4828439736046080000,
#  1.1166877939002664e+33,
#  516000.0,
#  -7052360211449217024,
#  6.371606622427782e+24,
#  6.7847074611631485e+40,
#  1.132020384768e+17,
#  64214304000,
#  2332774080000.0,
#  82121355912960000,
#  4712575395528000,
#  2.799992066276842e+43,
#  7252969651200000.0,
#  15554256000.0,
#  1.3958834553151488e+20,
#  805559040000.0,
#  8568713200320000,
#  6079500.0,
#  2.04375650992128e+17,
#  1.2503676898237347e+62,
#  452016000.0,
#  1.4275513531413454e+32,
#  6286695030000,
#  4502377686470063384,
#  1823519900160000.0,
#  898033500.0,
#  2.8438321399488e+17,
#  309476160000,
#  2.49254346204864e+17,
#  1373217300000.0,
#  290947500,
#  278528544000.0,
#  1.5172241908901558e+45,
#  4.6001259595368e+19,
#  13523328000.0,
#  445154149440000000,
#  9409377600000.0,
#  3.7523290757854003e+21,
#  -6299762597457189888,
#  1.2222285145723127e+37,
#  1535100.0,
#  1.535485107716266e+21,
#  331638685088256.0,
#  1.163890928573743e+27,
#  4269507840000.0,
#  2500.0,
#  7.876356438720209e+23,
#  4363117292886425600,
#  6573558884256000.0,
#  1.680419715136793e+32,
#  3.034738621736315e+25,
#  -4494525003120164864,
#  1.9448330648352966e+40,
#  1.6407674703316635e+33,
#  2446948503816615168,
#  5.951371153461327e+48,
#  7800000.0,
#  1.7489376884826e+17,
#  108144804768000,
#  900672507984085152,
#  2.0880368255270973e+22,
#  5.0410149310768265e+22,
#  2.454847742850048e+21,
#  2558190373200000,
#  2500.0,
#  2595840.0,
#  4107600000,
#  594624000.0,
#  445536000,
#  7776.0,
#  5336906097600000.0,
#  6961500,
#  1493842581000000,
#  2.1960726055827884e+28,
#  5.64001522177275e+18,
#  602000000.0,
#  250214850000.0,
#  257965344000.0,
#  2297551826553984000,
#  38864448000.0,
#  2641920.0,
#  1.4295892013352374e+24,
#  5945403240000.0,
#  1.2990475547973e+25,
#  1.070411819720028e+26,
#  92108352960000.0,
#  139338099210240000,
#  13045321536624000,
#  4.170648264707622e+22,
#  554830214400000.0,
#  2656500.0,
#  44505000.0,
#  9222595200000,
#  3.7470076529886e+17,
#  616896000,
#  68612544000.0,
#  1.3958834553151488e+20,
#  567000.0,
#  6.854468594448384e+18,
#  2.0486018157696e+17,
#  44098557414912000,
#  2.505671652685114e+25,
#  1.27196446341888e+22,
#  5.183343183965999e+28,
#  4.7195275615488e+16,
#  19292288400000.0,
#  1.5907476136559875e+42,
#  5072256.0,
#  1266693120000,
#  843281440444800000,
#  2.19222018183168e+17,
#  2830379715072000.0,
#  1.885772109312e+19,
#  5661749184000.0,
#  22345344.0,
#  155613249792000,
#  5.7453395212493275e+19,
#  1719900000.0]

# %%
tabela_lusiadas_relativa[frase.split()].prod()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-206-3c0141a44e89> in <module>
# ----> 1 tabela_lusiadas_relativa[frase.split()].prod()
#
# NameError: name 'tabela_lusiadas_relativa' is not defined
